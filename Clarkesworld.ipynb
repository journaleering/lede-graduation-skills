# %% [markdown]
# # Clarkesworld
#
# Source: https://clarkesworldmagazine.com/
#
# Description: Sci-fi/fantasy magazine
#
# **Topics:**
#
# * Scraping

# %% [markdown]
# ## Scrape the Clarkesworld homepage `4 points`
#
# I want a CSV file that includes a row for each story, including the columns:
#
# * Title
# * Byline
# * URL to story
# * Category (fiction/non-fiction/cover art)
# * Issue number (e.g. 180)
# * Publication date (e.g. September 2021)

# %% [markdown]
# ### Importing

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

response = requests.get("https://clarkesworldmagazine.com/")
soup = bs(response.text, 'html.parser')

# %% [markdown]
# ### Getting the information

# %%
results = soup.select('div.index-col1,div.index-col2')

rows = []

for r in results:
    print('----------')  
    issue = []
    row = {}
    row['Title'] = r.select_one('.story').text
    row['Byline'] = r.select_one('.byline').text
    row['URL to story'] = r.select_one('a').get('href')
    #row['URL to story'] = r.select_one('a').['href']
    row['Category'] = r.parent.p.text.strip()
    issue = r.parent.parent.h1.text.split('–')
    row['Issue number'] = issue[0].replace('ISSUE','').strip()
    row['Publication date'] = issue[1]
    rows.append(row)
    print(row)
# Out:
# ----------
# {'Title': 'The Dragon Project', 'Byline': 'by Naomi Kritzer', 'URL to story': 'https://clarkesworldmagazine.com/kritzer_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Saturn Devouring His Son', 'Byline': 'by EA Mylonas', 'URL to story': 'https://clarkesworldmagazine.com/mylonas_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Rain of Days', 'Byline': 'by Ray Nayler', 'URL to story': 'https://clarkesworldmagazine.com/nayler_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'The Memory of Water', 'Byline': 'by Tegan Moore', 'URL to story': 'https://clarkesworldmagazine.com/moore_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Wanting Things', 'Byline': 'by Cal Ritterhoff', 'URL to story': 'https://clarkesworldmagazine.com/ritterhoff_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'It Takes a Village', 'Byline': 'by Priya Chand', 'URL to story': 'https://clarkesworldmagazine.com/chand_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Meddling Fields', 'Byline': 'by R.T. Ester', 'URL to story': 'https://clarkesworldmagazine.com/ester_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Commencement Address', 'Byline': 'by Arthur Liu, translated by Stella Jiayue Zhu', 'URL to story': 'https://clarkesworldmagazine.com/liu_03_22', 'Category': 'FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Validating Rage: Women in Horror', 'Byline': 'by Carrie Sessarego', 'URL to story': 'https://clarkesworldmagazine.com/sessarego_03_22', 'Category': 'NON-FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Breaking the Gender Barrier: A Conversation with Regina Kanyu Wang and Yu Chen', 'Byline': 'by Arley Sorg', 'URL to story': 'https://clarkesworldmagazine.com/wang-chen_interview', 'Category': 'NON-FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'Friendship in the Time Of Kaiju: A Conversation with John Scalzi', 'Byline': 'by Arley Sorg', 'URL to story': 'https://clarkesworldmagazine.com/scalzi_interview_2022', 'Category': 'NON-FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': "Editor's Desk: The Best from 2021", 'Byline': 'by Neil Clarke', 'URL to story': 'https://clarkesworldmagazine.com/clarke_03_22', 'Category': 'NON-FICTION', 'Issue number': '186', 'Publication date': ' March 2022'}
# ----------
# {'Title': 'SurtiBot and Mister Oink', 'Byline': 'by Alejandro Burdisio', 'URL to story': 'https://clarkesworldmagazine.com/artbio_186', 'Category': 'COVER ART', 'Issue number': '186', 'Publication date': ' March 2022'}

# %% [markdown]
# ### Saving to CSV

# %%
df = pd.DataFrame(rows)
df.to_csv(path_or_buf='clarkesworld.csv')
df
# Out:
#                                                 Title  \
# 0                                  The Dragon Project
# 1                            Saturn Devouring His Son
# 2                                        Rain of Days
# 3                                 The Memory of Water
# 4                                      Wanting Things
# 5                                  It Takes a Village
# 6                                     Meddling Fields
# 7                                Commencement Address
# 8                    Validating Rage: Women in Horror
# 9   Breaking the Gender Barrier: A Conversation wi...
# 10  Friendship in the Time Of Kaiju: A Conversatio...
# 11                  Editor's Desk: The Best from 2021
# 12                           SurtiBot and Mister Oink
#
#                                             Byline  \
# 0                                 by Naomi Kritzer
# 1                                    by EA Mylonas
# 2                                    by Ray Nayler
# 3                                   by Tegan Moore
# 4                                by Cal Ritterhoff
# 5                                   by Priya Chand
# 6                                    by R.T. Ester
# 7   by Arthur Liu, translated by Stella Jiayue Zhu
# 8                              by Carrie Sessarego
# 9                                    by Arley Sorg
# 10                                   by Arley Sorg
# 11                                  by Neil Clarke
# 12                           by Alejandro Burdisio
#
#                                          URL to story     Category  \
# 0      https://clarkesworldmagazine.com/kritzer_03_22      FICTION
# 1      https://clarkesworldmagazine.com/mylonas_03_22      FICTION
# 2       https://clarkesworldmagazine.com/nayler_03_22      FICTION
# 3        https://clarkesworldmagazine.com/moore_03_22      FICTION
# 4   https://clarkesworldmagazine.com/ritterhoff_03_22      FICTION
# 5        https://clarkesworldmagazine.com/chand_03_22      FICTION
# 6        https://clarkesworldmagazine.com/ester_03_22      FICTION
# 7          https://clarkesworldmagazine.com/liu_03_22      FICTION
# 8    https://clarkesworldmagazine.com/sessarego_03_22  NON-FICTION
# 9   https://clarkesworldmagazine.com/wang-chen_int...  NON-FICTION
# 10  https://clarkesworldmagazine.com/scalzi_interv...  NON-FICTION
# 11      https://clarkesworldmagazine.com/clarke_03_22  NON-FICTION
# 12        https://clarkesworldmagazine.com/artbio_186    COVER ART
#
#    Issue number Publication date
# 0           186       March 2022
# 1           186       March 2022
# 2           186       March 2022
# 3           186       March 2022
# 4           186       March 2022
# 5           186       March 2022
# 6           186       March 2022
# 7           186       March 2022
# 8           186       March 2022
# 9           186       March 2022
# 10          186       March 2022
# 11          186       March 2022
# 12          186       March 2022

# %% [markdown]
# ## Auto-updating scraper `3 points`
#
# Using GitHub Actions, implement a scraper that will keep track of everything posted to the Clarkesworld homepage. For example, when issue 181 comes out it should *add to the CSV* instead of just replacing it.
#
# > Tip: `drop_duplicates` might save you a lot of effort at one point or another.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import os.path

response = requests.get("https://clarkesworldmagazine.com/")
soup = bs(response.text, 'html.parser')
results = soup.select('div.index-col1,div.index-col2')

rows = []

for r in results:
    issue = []
    row = {}
    try:    
        row['Title'] = r.select_one('.story').text
    except:
        row['Title'] = 'unbekannt'

    try:    
        row['Byline'] = r.select_one('.byline').text  
    except:
        row['Byline'] = 'unbekannt'

    try:    
        row['URL to story'] = r.select_one('a').get('href')
    except:
        row['URL to story'] = 'unbekannt'

    try:    
        row['Category'] = r.parent.p.text.strip()
    except:
        row['Category'] = 'unbekannt'

    try:    
        issue = r.parent.parent.h1.text.split('–')
        row['Issue number'] = issue[0].replace('ISSUE','').strip()
        row['Publication date'] = issue[1]
    except:
        row['Issue number'] = 'unbekannt'
        row['Publication date'] = 'unbekannt'
    rows.append(row)
  
if os.path.isfile('clarkesworld.csv'):
    df1 = pd.read_csv('clarkesworld.csv',index_col=0)
    df2 = pd.DataFrame(rows)
    frames = [df1,df2]
    df3 = pd.concat(frames)
    
else:
    df3 = pd.DataFrame(rows)

df3.drop_duplicates(subset='URL to story', keep='first', inplace=True,ignore_index=True) 
df3.to_csv('clarkesworld.csv')
df3
# Out:
# /Users/Jonas/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#                                                 Title  \
# 0                                  The Dragon Project
# 1                            Saturn Devouring His Son
# 2                                        Rain of Days
# 3                                 The Memory of Water
# 4                                      Wanting Things
# 5                                  It Takes a Village
# 6                                     Meddling Fields
# 7                                Commencement Address
# 8                    Validating Rage: Women in Horror
# 9   Breaking the Gender Barrier: A Conversation wi...
# 10  Friendship in the Time Of Kaiju: A Conversatio...
# 11                  Editor's Desk: The Best from 2021
# 12                           SurtiBot and Mister Oink
#
#                                             Byline  \
# 0                                 by Naomi Kritzer
# 1                                    by EA Mylonas
# 2                                    by Ray Nayler
# 3                                   by Tegan Moore
# 4                                by Cal Ritterhoff
# 5                                   by Priya Chand
# 6                                    by R.T. Ester
# 7   by Arthur Liu, translated by Stella Jiayue Zhu
# 8                              by Carrie Sessarego
# 9                                    by Arley Sorg
# 10                                   by Arley Sorg
# 11                                  by Neil Clarke
# 12                           by Alejandro Burdisio
#
#                                          URL to story     Category  \
# 0      https://clarkesworldmagazine.com/kritzer_03_22      FICTION
# 1      https://clarkesworldmagazine.com/mylonas_03_22      FICTION
# 2       https://clarkesworldmagazine.com/nayler_03_22      FICTION
# 3        https://clarkesworldmagazine.com/moore_03_22      FICTION
# 4   https://clarkesworldmagazine.com/ritterhoff_03_22      FICTION
# 5        https://clarkesworldmagazine.com/chand_03_22      FICTION
# 6        https://clarkesworldmagazine.com/ester_03_22      FICTION
# 7          https://clarkesworldmagazine.com/liu_03_22      FICTION
# 8    https://clarkesworldmagazine.com/sessarego_03_22  NON-FICTION
# 9   https://clarkesworldmagazine.com/wang-chen_int...  NON-FICTION
# 10  https://clarkesworldmagazine.com/scalzi_interv...  NON-FICTION
# 11      https://clarkesworldmagazine.com/clarke_03_22  NON-FICTION
# 12        https://clarkesworldmagazine.com/artbio_186    COVER ART
#
#    Issue number Publication date
# 0           186       March 2022
# 1           186       March 2022
# 2           186       March 2022
# 3           186       March 2022
# 4           186       March 2022
# 5           186       March 2022
# 6           186       March 2022
# 7           186       March 2022
# 8           186       March 2022
# 9           186       March 2022
# 10          186       March 2022
# 11          186       March 2022
# 12          186       March 2022
