# %% [markdown]
# # Upworthy A/B title testing `5 points`
#
# Source: https://www.nature.com/articles/s41597-021-00934-7 and https://upworthy.natematias.com/.
#
# The dataset itself is kind of a pain to get to, and can be downloaded directly from [here](https://osf.io/vy8mj/download), as linked to from [this page](https://osf.io/vy8mj/).
#
# Description from [Data Is Plural](https://www.data-is-plural.com/archive/2021-08-18-edition/):
#
# > The Upworthy Research Archive describes 32,000+ headline-testing experiments conducted in 2013–15 by Upworthy, the online publication that popularized a once-ubiquitous style of headline. The dataset, contributed by the publication to a team of academics, is split into three tranches for use in different phases of research. In total, it covers 150,000+ headline-plus-image permutations; for each, it provides the headline, an image identifier, the number of viewers assigned to see it, the number who clicked, and other details.
#
# ### Topis covered
#
# * String functions
# * Reading and understanding data dictionaries
# * Sentiment analysis

# %% [markdown]
# ## Two questions about questions `1 point`
#
#
# Headlines that end in questions are so common there's even a rule about it: Betteridge's law of headlines! It states "Any headline that ends in a question mark can be answered by the word no."
#
# ### How often were Upworthy headlines phrased as questions?

# %%
import pandas as pd

df1 = pd.read_csv('upworthy-archive-confirmatory-packages-03.12.2020.csv', low_memory=False)
df1.loc[0].headline
# Out:
# 'Let’s See … Hire Cops, Pay Teachers, Buy Books For Schools. Or Kill People. Hard Choice, Right?'

# %%
df1['headline'] = df1['headline'].astype(str)
#Absolute number of headlines that were phrased as a question
df1[df1['headline'].str.contains('?', regex=False)].headline.count()
# Out:
# 15992

# %%
#Percentage of all headlines that were phrased as a question
(df1[df1['headline'].str.contains('?', regex=False)].headline.count()/\
df1.headline.count()\
*100).round(2)
# Out:
# 15.15

# %% [markdown]
# ### Are headlines with question marks more likely to succeed than ones without?
#
# Along with your actual answer, defend what you mean by "succeed" (for example, what column you picked to represent success). You probably want to read the "Data Records" section from the source."

# %%
#Take the mean value of the significance column (Question = True)
df1[df1['headline'].str.contains('?', regex=False)].significance.mean()
# Out:
# 37.5809779889945

# %%
#Take the mean value of the significance column (Question = False)
df1[~df1['headline'].str.contains('?', regex=False)].significance.mean()
# Out:
# 41.15700041313547

# %% [markdown]
# Articles with a higher significance value were more lickely to be clicked on.
# Question --> less likely to succeed

# %% [markdown]
# ### Upworthy was thought of as an "obnoxiously positive clickbait" kind of site. Does the data support this? `3 points`

# %%
df1.head(1)
# Out:
#    Unnamed: 0               created_at               updated_at  \
# 0          11  2014-11-20 11:33:26.475  2016-04-02 16:25:54.046
#
#        clickability_test_id                           excerpt  \
# 0  546dd17e26714c82cc00001c  Things that matter. Pass 'em on.
#
#                                             headline  \
# 0  Let’s See … Hire Cops, Pay Teachers, Buy Books...
#
#                                                 lede  \
# 0  <p>Iff you start with the basic fact that inno...
#
#                                                 slug  \
# 0  let-s-see-hire-cops-pay-teachers-buy-books-for...
#
#               eyecatcher_id  impressions  clicks  significance  first_place  \
# 0  546dce659ad54ec65b000041         3118       8           0.1        False
#
#    winner share_text square  test_week
# 0   False        NaN    NaN     201446

# %%
from textblob import TextBlob
from textblob import Blobber
from textblob.sentiments import NaiveBayesAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import nltk

nltk.download('vader_lexicon')
nltk.download('movie_reviews')
nltk.download('punkt')

# %%
df2 = df1.head(2000)

sia = SIA()
blobber = Blobber(analyzer=NaiveBayesAnalyzer())

def get_scores(content):
    blob = TextBlob(content)
    nb_blob = blobber(content)
    sia_scores = sia.polarity_scores(content)
    
    return pd.Series({
        'content': content,
        'textblob': blob.sentiment.polarity,
        'textblob_bayes': nb_blob.sentiment.p_pos - nb_blob.sentiment.p_neg,
        'nltk': sia_scores['compound'],
    })

scores = df2.headline.apply(get_scores)
scores.style.background_gradient(cmap='RdYlGn', axis=None, low=0.4, high=0.4)
# Out:
# <style  type="text/css" >
# #T_1e972_row0_col1,#T_1e972_row387_col2,#T_1e972_row431_col1,#T_1e972_row512_col2,#T_1e972_row602_col2,#T_1e972_row621_col1,#T_1e972_row745_col2,#T_1e972_row746_col2,#T_1e972_row865_col2,#T_1e972_row867_col2,#T_1e972_row904_col1,#T_1e972_row968_col2,#T_1e972_row1261_col2,#T_1e972_row1309_col1,#T_1e972_row1459_col2,#T_1e972_row1478_col2,#T_1e972_row1481_col2,#T_1e972_row1482_col2,#T_1e972_row1486_col2,#T_1e972_row1685_col2,#T_1e972_row1704_col1,#T_1e972_row1715_col2,#T_1e972_row1723_col2,#T_1e972_row1927_col1{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_1e972_row0_col2,#T_1e972_row67_col2,#T_1e972_row102_col3,#T_1e972_row164_col3,#T_1e972_row213_col3,#T_1e972_row401_col2,#T_1e972_row465_col3,#T_1e972_row493_col3,#T_1e972_row577_col3,#T_1e972_row673_col3,#T_1e972_row674_col3,#T_1e972_row675_col3,#T_1e972_row719_col1,#T_1e972_row753_col1,#T_1e972_row944_col1,#T_1e972_row983_col3,#T_1e972_row1073_col2,#T_1e972_row1091_col2,#T_1e972_row1104_col2,#T_1e972_row1128_col2,#T_1e972_row1163_col1,#T_1e972_row1171_col2,#T_1e972_row1417_col2,#T_1e972_row1520_col2,#T_1e972_row1525_col2,#T_1e972_row1582_col3,#T_1e972_row1620_col2,#T_1e972_row1630_col3,#T_1e972_row1666_col1,#T_1e972_row1890_col3,#T_1e972_row1891_col3,#T_1e972_row1892_col3,#T_1e972_row1893_col3,#T_1e972_row1894_col3,#T_1e972_row1895_col3,#T_1e972_row1983_col3,#T_1e972_row1984_col3,#T_1e972_row1985_col3,#T_1e972_row1986_col3,#T_1e972_row1987_col3,#T_1e972_row1988_col3{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_1e972_row0_col3,#T_1e972_row501_col3,#T_1e972_row552_col2,#T_1e972_row571_col2,#T_1e972_row574_col2,#T_1e972_row576_col2,#T_1e972_row579_col2,#T_1e972_row618_col2,#T_1e972_row619_col2,#T_1e972_row657_col3,#T_1e972_row661_col2,#T_1e972_row662_col2,#T_1e972_row663_col2,#T_1e972_row793_col2,#T_1e972_row1145_col1,#T_1e972_row1147_col3,#T_1e972_row1148_col3,#T_1e972_row1149_col1,#T_1e972_row1730_col2,#T_1e972_row1731_col2,#T_1e972_row1732_col2,#T_1e972_row1736_col2{
#             background-color:  #fca85e;
#             color:  #000000;
#         }#T_1e972_row1_col1,#T_1e972_row1_col3,#T_1e972_row76_col1,#T_1e972_row79_col1,#T_1e972_row79_col3,#T_1e972_row80_col1,#T_1e972_row80_col3,#T_1e972_row103_col1,#T_1e972_row103_col3,#T_1e972_row111_col3,#T_1e972_row124_col1,#T_1e972_row124_col3,#T_1e972_row125_col1,#T_1e972_row125_col3,#T_1e972_row127_col1,#T_1e972_row127_col3,#T_1e972_row151_col1,#T_1e972_row179_col1,#T_1e972_row179_col3,#T_1e972_row189_col2,#T_1e972_row192_col2,#T_1e972_row193_col2,#T_1e972_row194_col1,#T_1e972_row196_col2,#T_1e972_row197_col1,#T_1e972_row221_col1,#T_1e972_row225_col1,#T_1e972_row225_col3,#T_1e972_row321_col1,#T_1e972_row321_col3,#T_1e972_row370_col1,#T_1e972_row371_col1,#T_1e972_row372_col1,#T_1e972_row373_col1,#T_1e972_row408_col1,#T_1e972_row425_col2,#T_1e972_row449_col3,#T_1e972_row453_col3,#T_1e972_row458_col2,#T_1e972_row459_col2,#T_1e972_row470_col3,#T_1e972_row479_col3,#T_1e972_row529_col2,#T_1e972_row602_col3,#T_1e972_row635_col2,#T_1e972_row638_col2,#T_1e972_row665_col2,#T_1e972_row735_col3,#T_1e972_row771_col3,#T_1e972_row772_col3,#T_1e972_row809_col3,#T_1e972_row928_col3,#T_1e972_row948_col1,#T_1e972_row965_col1,#T_1e972_row975_col1,#T_1e972_row1107_col3,#T_1e972_row1202_col1,#T_1e972_row1204_col1,#T_1e972_row1207_col1,#T_1e972_row1576_col3,#T_1e972_row1598_col1,#T_1e972_row1647_col1,#T_1e972_row1721_col3,#T_1e972_row1796_col1,#T_1e972_row1811_col3,#T_1e972_row1814_col3,#T_1e972_row1866_col2,#T_1e972_row1915_col1,#T_1e972_row1916_col1,#T_1e972_row1917_col1{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_1e972_row1_col2,#T_1e972_row79_col2,#T_1e972_row124_col2,#T_1e972_row912_col2,#T_1e972_row1322_col2,#T_1e972_row1473_col2{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_1e972_row2_col1,#T_1e972_row77_col1,#T_1e972_row101_col1,#T_1e972_row104_col3,#T_1e972_row105_col3,#T_1e972_row106_col3,#T_1e972_row107_col3,#T_1e972_row108_col3,#T_1e972_row109_col3,#T_1e972_row132_col1,#T_1e972_row149_col3,#T_1e972_row156_col3,#T_1e972_row157_col3,#T_1e972_row158_col3,#T_1e972_row159_col3,#T_1e972_row378_col1,#T_1e972_row380_col1,#T_1e972_row391_col2,#T_1e972_row394_col2,#T_1e972_row415_col2,#T_1e972_row430_col2,#T_1e972_row437_col2,#T_1e972_row447_col1,#T_1e972_row450_col1,#T_1e972_row451_col1,#T_1e972_row463_col2,#T_1e972_row480_col1,#T_1e972_row503_col1,#T_1e972_row506_col3,#T_1e972_row534_col1,#T_1e972_row553_col1,#T_1e972_row578_col1,#T_1e972_row588_col1,#T_1e972_row652_col1,#T_1e972_row687_col1,#T_1e972_row693_col2,#T_1e972_row721_col2,#T_1e972_row727_col3,#T_1e972_row778_col2,#T_1e972_row785_col1,#T_1e972_row802_col1,#T_1e972_row803_col1,#T_1e972_row819_col3,#T_1e972_row822_col1,#T_1e972_row829_col3,#T_1e972_row837_col1,#T_1e972_row842_col1,#T_1e972_row847_col1,#T_1e972_row857_col3,#T_1e972_row860_col1,#T_1e972_row861_col1,#T_1e972_row976_col1,#T_1e972_row1015_col2,#T_1e972_row1030_col1,#T_1e972_row1031_col1,#T_1e972_row1040_col1,#T_1e972_row1042_col2,#T_1e972_row1043_col1,#T_1e972_row1045_col1,#T_1e972_row1050_col1,#T_1e972_row1054_col3,#T_1e972_row1064_col3,#T_1e972_row1066_col1,#T_1e972_row1080_col3,#T_1e972_row1089_col1,#T_1e972_row1094_col1,#T_1e972_row1095_col3,#T_1e972_row1098_col2,#T_1e972_row1105_col3,#T_1e972_row1107_col1,#T_1e972_row1151_col1,#T_1e972_row1152_col1,#T_1e972_row1157_col1,#T_1e972_row1203_col1,#T_1e972_row1217_col1,#T_1e972_row1218_col1,#T_1e972_row1252_col1,#T_1e972_row1258_col1,#T_1e972_row1304_col1,#T_1e972_row1306_col1,#T_1e972_row1329_col3,#T_1e972_row1340_col1,#T_1e972_row1345_col1,#T_1e972_row1347_col1,#T_1e972_row1382_col1,#T_1e972_row1408_col1,#T_1e972_row1428_col1,#T_1e972_row1456_col2,#T_1e972_row1468_col1,#T_1e972_row1476_col2,#T_1e972_row1479_col2,#T_1e972_row1603_col1,#T_1e972_row1685_col1,#T_1e972_row1723_col1,#T_1e972_row1812_col2,#T_1e972_row1830_col3,#T_1e972_row1855_col1,#T_1e972_row1864_col1,#T_1e972_row1964_col1{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_1e972_row2_col2,#T_1e972_row211_col2,#T_1e972_row278_col2,#T_1e972_row891_col2,#T_1e972_row926_col2,#T_1e972_row1039_col2,#T_1e972_row1043_col2,#T_1e972_row1089_col2,#T_1e972_row1094_col2,#T_1e972_row1160_col3,#T_1e972_row1237_col3,#T_1e972_row1336_col3,#T_1e972_row1345_col2,#T_1e972_row1408_col2,#T_1e972_row1519_col2{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_1e972_row2_col3,#T_1e972_row627_col3,#T_1e972_row672_col3,#T_1e972_row762_col3,#T_1e972_row799_col3,#T_1e972_row932_col3,#T_1e972_row939_col3,#T_1e972_row941_col3,#T_1e972_row953_col3,#T_1e972_row956_col3,#T_1e972_row988_col3,#T_1e972_row990_col3,#T_1e972_row991_col3,#T_1e972_row1099_col2,#T_1e972_row1143_col3,#T_1e972_row1354_col3,#T_1e972_row1609_col3,#T_1e972_row1694_col3,#T_1e972_row1703_col3,#T_1e972_row1738_col3,#T_1e972_row1746_col3,#T_1e972_row1748_col3,#T_1e972_row1749_col3,#T_1e972_row1751_col3,#T_1e972_row1816_col3{
#             background-color:  #fdb768;
#             color:  #000000;
#         }#T_1e972_row3_col1,#T_1e972_row7_col1,#T_1e972_row8_col1,#T_1e972_row9_col1,#T_1e972_row10_col1,#T_1e972_row12_col1,#T_1e972_row13_col1,#T_1e972_row14_col1,#T_1e972_row15_col1,#T_1e972_row16_col1,#T_1e972_row17_col1,#T_1e972_row18_col1,#T_1e972_row19_col1,#T_1e972_row20_col1,#T_1e972_row21_col1,#T_1e972_row22_col1,#T_1e972_row23_col1,#T_1e972_row25_col1,#T_1e972_row30_col1,#T_1e972_row31_col1,#T_1e972_row32_col1,#T_1e972_row33_col1,#T_1e972_row34_col1,#T_1e972_row37_col1,#T_1e972_row49_col1,#T_1e972_row50_col1,#T_1e972_row51_col1,#T_1e972_row53_col1,#T_1e972_row54_col1,#T_1e972_row55_col1,#T_1e972_row71_col1,#T_1e972_row164_col1,#T_1e972_row213_col1,#T_1e972_row335_col1,#T_1e972_row396_col2,#T_1e972_row488_col1,#T_1e972_row538_col1,#T_1e972_row548_col2,#T_1e972_row549_col2,#T_1e972_row551_col2,#T_1e972_row623_col1,#T_1e972_row623_col2,#T_1e972_row627_col2,#T_1e972_row633_col2,#T_1e9

# %% [markdown]
# ### Were the selected headlines more likely to be positive or negative? `1 point`

# %%
print(scores['textblob'].mean())
print(scores['textblob_bayes'].mean())
print(scores['nltk'].mean())
# Out:
# 0.07325566438191439
# 0.15946016656446485
# 0.0038070499999999993

# %% [markdown]
# The selected headlines were more likely to be positive.
